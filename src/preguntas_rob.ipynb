# %% [markdown]
# # Preguntas

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
DATAPATH = '../data/csv/data_rick.csv'
df_rick = pd.read_csv(DATAPATH)


df_rick.head()
# Out:
#                  state  year  week  week_cases  m_accum  f_accum  cases_accum
# 0       Aguascalientes  2013     2           0        0        0            0
# 1      Baja California  2013     2           0        0        0            3
# 2  Baja California Sur  2013     2           0        0        0            0
# 3             Campeche  2013     2           0        0        0            0
# 4             Coahuila  2013     2           0        0        0            1

# %% [markdown]
# ## ¿Número de casos por año, México (gráfica)?

# %% [markdown]
# La última semana registrada de cada año contiene los valores acumulados durante todo el año para cada columna. De lo anterior podemos deducir que los casos que se presentaron en total en el año son:
#
# \begin{align}
# \sum{k=1}
# \end{align}
#
# **update formula**
#
# Última semana por año:
# - 2013: sem 53
# - 2014: sem 53
# - 2015: sem 52
# - 2016: sem 51
# - 2017: sem 14

# %%
lw2013 = df_rick.loc[(df_rick['year'] == 2013) & (df_rick['week'] == 53)]    # seleccionar última semana de 2013
cases2013 = lw2013['cases_accum'].sum()    # total de casos en 2013
# Out:
# 1032

# %%
lw2014 = df_rick.loc[(df_rick['year'] == 2014) ]

# %%
lw2014
# Out:
#                     state  year  week  week_cases  m_accum  f_accum  \
# 1664       Aguascalientes  2014     2           0        0        0
# 1665      Baja California  2014     2           2        1        1
# 1666  Baja California Sur  2014     2           0        0        0
# 1667             Campeche  2014     2           0        0        0
# 1668             Coahuila  2014     2           0        0        0
# 1669               Colima  2014     2           0        0        0
# 1670              Chiapas  2014     2           0        0        0
# 1671            Chihuahua  2014     2           0        0        0
# 1672     Distrito Federal  2014     2           0        0        0
# 1673              Durango  2014     2           0        0        0
# 1674           Guanajuato  2014     2           0        0        0
# 1675             Guerrero  2014     2           0        0        0
# 1676              Hidalgo  2014     2           0        0        0
# ...
