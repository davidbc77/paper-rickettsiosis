# %%
import pandas as pd 
import numpy as np

# %%
DATA2016 = '../data/2016.xlsx'
CSV = '../data/csv/2016.csv'
xls = pd.ExcelFile(DATA2016)

df = pd.read_excel(DATA2016, header=None)

# %%
df
# Out:
#                       0  1  2  3  4  5  6  7  8
# 0        Aguascalientes  -  -  -  -  -  -  -  -
# 1       Baja California  -  -  -  -  -  -  -  -
# 2   Baja California Sur  -  -  -  -  -  -  -  -
# 3              Campeche  -  -  -  -  -  -  -  -
# 4              Coahuila  -  -  -  -  -  -  -  -
# 5                Colima  -  -  -  -  -  -  -  -
# 6               Chiapas  -  -  -  -  -  -  -  -
# 7             Chihuahua  -  -  -  -  -  -  -  -
# 8      Ciudad de México  -  -  -  -  -  -  -  -
# 9               Durango  -  -  -  -  -  -  -  -
# 10           Guanajuato  -  -  -  -  -  -  -  -
# 11             Guerrero  -  -  -  -  -  -  -  -
# 12              Hidalgo  -  -  -  -  -  -  -  -
# 13              Jalisco  -  -  -  -  -  -  -  -
# 14               México  -  -  -  -  -  -  -  -
# 15            Michoacán  -  -  -  -  -  -  -  -
# 16              Morelos  -  -  -  -  -  -  -  -
# 17              Nayarit  -  -  -  -  -  -  -  -
# 18           Nuevo León  -  -  -  -  -  -  -  -
# ...

# %%
df.drop(32, inplace=True)    # drop "TOTAL" row

# %%
df
# Out:
#                       0  1  2  3  4  5  6  7  8
# 0        Aguascalientes  -  -  -  -  -  -  -  -
# 1       Baja California  -  -  -  -  -  -  -  -
# 2   Baja California Sur  -  -  -  -  -  -  -  -
# 3              Campeche  -  -  -  -  -  -  -  -
# 4              Coahuila  -  -  -  -  -  -  -  -
# 5                Colima  -  -  -  -  -  -  -  -
# 6               Chiapas  -  -  -  -  -  -  -  -
# 7             Chihuahua  -  -  -  -  -  -  -  -
# 8      Ciudad de México  -  -  -  -  -  -  -  -
# 9               Durango  -  -  -  -  -  -  -  -
# 10           Guanajuato  -  -  -  -  -  -  -  -
# 11             Guerrero  -  -  -  -  -  -  -  -
# 12              Hidalgo  -  -  -  -  -  -  -  -
# 13              Jalisco  -  -  -  -  -  -  -  -
# 14               México  -  -  -  -  -  -  -  -
# 15            Michoacán  -  -  -  -  -  -  -  -
# 16              Morelos  -  -  -  -  -  -  -  -
# 17              Nayarit  -  -  -  -  -  -  -  -
# 18           Nuevo León  -  -  -  -  -  -  -  -
# ...

# %%
df_usa = pd.read_csv('../data/nndss-table-ii.-spotted-fever-rickettsiosis-to-syphilis.csv')

# %%
df_usa.head()
# Out:
#   Reporting Area  MMWR Year  MMWR Week  \
# 0  UNITED STATES       2016          1
# 1    NEW ENGLAND       2016          1
# 2    CONNECTICUT       2016          1
# 3          MAINE       2016          1
# 4  MASSACHUSETTS       2016          1
#
#    Spotted Fever Rickettsiosis (including RMSF)§, Confirmed, Current week  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Spotted Fever Rickettsiosis (including RMSF)§, Confirmed, Current week, flag  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
#
# ...

# %%
df = pd.read_csv(CSV)

# %%
df.year.unique()
# Out:
# array([2016], dtype=int64)

# %%
df
# Out:
#                     state  week_cases  m_accum  f_accum  2015_acum  week  year
# 0          Aguascalientes         NaN      NaN      NaN        NaN     1  2016
# 1         Baja California         NaN      NaN      NaN        NaN     1  2016
# 2     Baja California Sur         NaN      NaN      NaN        NaN     1  2016
# 3                Campeche         NaN      NaN      NaN        NaN     1  2016
# 4                Coahuila         NaN      NaN      NaN        NaN     1  2016
# 5                  Colima         NaN      NaN      NaN        NaN     1  2016
# 6                 Chiapas         NaN      NaN      NaN        NaN     1  2016
# 7               Chihuahua         NaN      NaN      NaN        NaN     1  2016
# 8        Ciudad de México         NaN      NaN      NaN        NaN     1  2016
# 9                 Durango         NaN      NaN      NaN        NaN     1  2016
# 10             Guanajuato         NaN      NaN      NaN        NaN     1  2016
# ...
